# %%
import torch
from torch import nn

net = nn.Sequential(nn.LazyLinear(256), nn.ReLU(), nn.Linear(256, 10))
print(net)

[net[i].state_dict() for i in range(len(net))]
# Out:
# Sequential(
#   (0): LazyLinear(in_features=0, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=10, bias=True)
# )
# [OrderedDict([('weight', <UninitializedParameter>),
#               ('bias', <UninitializedParameter>)]),
#  OrderedDict(),
#  OrderedDict([('weight',
#                tensor([[-0.0013, -0.0351, -0.0173,  ...,  0.0592, -0.0535, -0.0228],
#                        [ 0.0162,  0.0549,  0.0514,  ..., -0.0268, -0.0149,  0.0176],
#                        [-0.0194,  0.0146, -0.0074,  ...,  0.0591,  0.0047, -0.0071],
#                        ...,
#                        [-0.0120, -0.0140,  0.0180,  ..., -0.0597, -0.0077, -0.0280],
#                        [ 0.0178, -0.0350, -0.0214,  ..., -0.0552, -0.0201, -0.0139],
#                        [ 0.0093, -0.0310,  0.0155,  ...,  0.0036, -0.0098,  0.0203]])),
#               ('bias',
#                tensor([-0.0222, -0.0145,  0.0526, -0.0440, -0.0494, -0.0182,  0.0081, -0.0109,
#                        -0.0563,  0.0211]))])]

# %%
low = torch.finfo(torch.float32).min / 10
high = torch.finfo(torch.float32).max / 10

X = torch.zeros([2, 20], dtype=torch.float32).uniform_(low, high)

net(X)

print(net)
# Out:
# Sequential(
#   (0): Linear(in_features=20, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=10, bias=True)
# )
